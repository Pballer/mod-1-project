# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
imdb_title_crew = pd.read_csv('./data/imdb.title.crew.csv.gz')

# %%
imdb_title_crew.head(20)
# Out:
#         tconst                      directors  \
# 0    tt0285252                      nm0899854
# 1    tt0438973                            NaN
# 2    tt0462036                      nm1940585
# 3    tt0835418                      nm0151540
# 4    tt0878654  nm0089502,nm2291498,nm2292011
# 5    tt0879859                      nm2416460
# 6    tt0996958                      nm2286991
# 7    tt0999913                      nm0527109
# 8   tt10003792                     nm10539228
# 9   tt10005130                     nm10540239
# 10  tt10005378                      nm9232888
# 11  tt10011102                      nm4853354
# 12   tt1002965                      nm0860520
# 13  tt10036406                     nm10553970
# 14  tt10039152                      nm6021959
# 15  tt10042456                      nm6051389
# 16  tt10055770                      nm8351963
# 17  tt10056334                     nm10563021
# 18  tt10059624                      nm0472248
# ...

# %%
# Okay, multiple directors and writers might be an issue
# What do we have missing?
imdb_title_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
# tconst       146144 non-null object
# directors    140417 non-null object
# writers      110261 non-null object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
# Nothing seems to be missing from titles (tconst)
# More writers missing than directors
# All variables are of the right type (strings
print(imdb_title_crew.directors.isna().sum())
print(imdb_title_crew.writers.isna().sum())
# Out:
# 5727
# 35883

# %%
imdb_title_crew.describe().T
# Out:
#             count  unique        top freq
# tconst     146144  146144  tt6954298    1
# directors  140417   98525  nm3266654   62
# writers    110261   91920  nm0000636   80

# %%
# Looks like each tconst is unique (no duplicates)
# more uniqe directors than writers (disregarding combos)
# confirm the above
imdb_title_crew.directors.value_counts()
# Out:
# nm3266654                        62
# nm5592581                        48
# nm2682776                        48
# nm3583561                        46
# nm0183659                        44
# nm1297226                        42
# nm2551464                        39
# nm2410514                        38
# nm0772905                        37
# nm3127702                        33
# nm3008388                        32
# nm0591472                        30
# nm2428088                        28
# nm3212330                        27
# nm3220274                        27
# nm0213983                        26
# nm2869957                        25
# nm1008445                        25
# nm4558430                        25
# nm3032813                        25
# nm5954636                        24
# nm2096009                        24
# nm0890060                        24
# nm4356119                        24
# nm0482774                        23
# nm4341114                        23
# ...

# %%
# Conclusion:
# We have to ID these with IMDB_name
