# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
imdb_tn_genres_revenues = pd.read_pickle('../processed_data/imdb_tn_genres_revenues.pkl')

# %%
imdb_tn_genres_revenues.head(10)
# Out:
#       tconst                    primary_title  \
# 0  tt0249516                       Foodfight!
# 1  tt0359950  The Secret Life of Walter Mitty
# 2  tt0365907      A Walk Among the Tombstones
# 3  tt0369610                   Jurassic World
# 4  tt0376136                    The Rum Diary
# 5  tt0383010                The Three Stooges
# 6  tt0393049                 Anderson's Cross
# 7  tt0398286                          Tangled
# 8  tt0401729                      John Carter
# 9  tt0427152              Dinner for Schmucks
#
#                     original_title  start_year  runtime_minutes  \
# 0                       Foodfight!        2012             91.0
# 1  The Secret Life of Walter Mitty        2013            114.0
# 2      A Walk Among the Tombstones        2014            114.0
# 3                   Jurassic World        2015            124.0
# 4                    The Rum Diary        2011            119.0
# 5                The Three Stooges        2012             92.0
# ...

# %%
imdb_tn_genres_revenues.describe().T
# Out:
#                     count          mean           std      min           25%  \
# start_year         1578.0  2.013894e+03  2.575841e+00   2010.0  2.012000e+03
# runtime_minutes    1552.0  1.067403e+02  1.923857e+01      4.0  9.400000e+01
# averagerating      1529.0  6.289797e+00  1.073595e+00      1.6  5.700000e+00
# numvotes           1529.0  1.129217e+05  1.630765e+05      5.0  1.285100e+04
# id                 1578.0  5.056907e+01  2.879764e+01      1.0  2.500000e+01
# production_budget  1578.0  4.374332e+07  5.547434e+07  15000.0  7.000000e+06
# domestic_gross     1578.0  5.446392e+07  8.373955e+07      0.0  1.904769e+06
# worldwide_gross    1578.0  1.368243e+08  2.307847e+08      0.0  6.765501e+06
# release_year       1578.0  2.013894e+03  2.575841e+00   2010.0  2.012000e+03
# dom_roi            1578.0  1.787982e+02  6.432053e+02      0.0  2.204750e+01
# world_roi          1578.0  3.619600e+02  1.180303e+03      0.0  6.289750e+01
#
# ...

# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Histograms

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
imdb_tn_genres_revenues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1578 entries, 0 to 1523
# Data columns (total 19 columns):
# tconst               1578 non-null object
# primary_title        1578 non-null object
# original_title       1578 non-null object
# start_year           1578 non-null int64
# runtime_minutes      1552 non-null float64
# genres               1572 non-null object
# averagerating        1529 non-null float64
# numvotes             1529 non-null float64
# _merge               1578 non-null category
# id                   1578 non-null int64
# release_date         1578 non-null datetime64[ns]
# movie                1578 non-null object
# production_budget    1578 non-null int64
# domestic_gross       1578 non-null int64
# worldwide_gross      1578 non-null int64
# release_year         1578 non-null int64
# dom_roi              1578 non-null float64
# world_roi            1578 non-null float64
# main_genre           1572 non-null category
# ...

# %% [markdown]
# ### Histogram for Domestic Return on Investment

# %%
imdb_tn_genres_revenues.hist(column="dom_roi", bins=15)
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000225939F8DA0>]],
#       dtype=object)

# %%
imdb_tn_genres_revenues.hist(column='world_roi', bins=4)
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022594A77550>]],
#       dtype=object)

# %%
imdb_tn_genres_revenues.hist(column="revenue", bins=15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-2fa81b982c69> in <module>
# ----> 1 imdb_tn_genres_revenues.hist(column="revenue", bins=15)
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2397         if not isinstance(column, (list, np.ndarray, ABCIndexClass)):
#    2398             column = [column]
# -> 2399         data = data[column]
#    2400     data = data._get_numeric_data()
#    2401     naxes = len(data.columns)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
# ...

# %%
imdb_tn_genres_revenues.hist(imdb_tn_genres_revenues, column=dom_roi, by=None, grid=True, 
                             xlabelsize=None, xrot=None, ylabelsize=None, yrot=None, ax=None, 
                             sharex=False, sharey=False, figsize=None, layout=None, bins=10, **kwds)
